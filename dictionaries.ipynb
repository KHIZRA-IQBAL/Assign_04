# %% [markdown]
# <a href="https://colab.research.google.com/github/KHIZRA-IQBAL/Assign_04/blob/main/dictionaries.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
#00_count_num
def count_numbers():
    count_dict = {}

    while True:
        num = input("Enter a number (or 'Exit' to quit): ")

        if num.lower() == 'exit':
            break

        if num.isdigit():
            num = int(num)
            count_dict[num] = count_dict.get(num, 0) + 1
        else:
            print("Invalid input. Please enter a number or 'Exit' to quit.")

    return count_dict

def display_count(count_dict):
    print("\nNumber Count:")
    for num, count in count_dict.items():
        print(f"{num}: {count}")

counts = count_numbers()
display_count(counts)
# Out:
# Enter a number (or 'Exit' to quit): 4
# Enter a number (or 'Exit' to quit): 3
# Enter a number (or 'Exit' to quit): 4
# Enter a number (or 'Exit' to quit): 5
# Enter a number (or 'Exit' to quit): 6
# Enter a number (or 'Exit' to quit): 7
# Enter a number (or 'Exit' to quit): 8
# Enter a number (or 'Exit' to quit): 4
# Enter a number (or 'Exit' to quit):
# Invalid input. Please enter a number or 'Exit' to quit.
# Enter a number (or 'Exit' to quit): exit
#
# Number Count:
# 4: 3
# 3: 1
# 5: 1
# 6: 1
# 7: 1
# 8: 1

# %%
#01_phonebook
def add_contact(phonebook):
    name = input("Enter the name: ")
    phone = input("Enter the phone number: ")
    email = input("Enter the email: ")

    if name in phonebook:
        print(f"{name} already exists in the phonebook.")
    else:
        phonebook[name] = {'Phone': phone, 'Email': email}
        print(f"{name} added to the phonebook.")
def search_contact(phonebook):
    name = input("Enter the name to search: ")
    if name in phonebook:
       print(f"{name}: {phonebook[name]}")
    else:
        print(f"{name} not found in the phonebook.")
def deelete_contact(phonebook):
    name = input("Enter the name to delete: ")
    if name in phonebook:
        del phonebook[name]
        print(f"{name} deleted from the phonebook.")
    else:
        print(f"{name} not found in the phonebook.")

def display_phonebook(phonebook):
    if not phonebook:
        print("Phonebook contacts list")
        for name, contact_info in phonebook.items():
            print(f"{name}: {contact_info}")
        else:
          print("Phonebook is empty.")
phonebook={}
while True:
    print("\nPhonebook Menu:")
    print("1. Add Contact")
    print("2. Search Contact")
    print("3. Delete Contact")
    print("4. Display Phonebook")
    print("5. Exit")
    choice = input("Enter your choice (1/2/3/4/5): ")
    if choice == '1':
        add_contact(phonebook)
    elif choice == '2':
        search_contact(phonebook)
    elif choice == '3':
        deelete_contact(phonebook)
    elif choice == '4':
        display_phonebook(phonebook)
    elif choice == '5':
        print("Exiting Phonebook. Goodbye!")
        break
    else:
        print("Invalid choice. Please select a valid option.")
# Out:
# Phonebook Menu:
# 1. Add Contact
# 2. Search Contact
# 3. Delete Contact
# 4. Display Phonebook
# 5. Exit
# khizra added to the phonebook.
#
# Phonebook Menu:
# 1. Add Contact
# 2. Search Contact
# 3. Delete Contact
# 4. Display Phonebook
# 5. Exit
# khzra not found in the phonebook.
#
# Phonebook Menu:
# 1. Add Contact
# 2. Search Contact
# 3. Delete Contact
# 4. Display Phonebook
# 5. Exit
# Invalid choice. Please select a valid option.
#
# Phonebook Menu:
# 1. Add Contact
# 2. Search Contact
# 3. Delete Contact
# 4. Display Phonebook
# 5. Exit
# Invalid choice. Please select a valid option.
#
# Phonebook Menu:
# 1. Add Contact
# 2. Search Contact
# 3. Delete Contact
# 4. Display Phonebook
# 5. Exit
# Invalid choice. Please select a valid option.
#
# Phonebook Menu:
# 1. Add Contact
# 2. Search Contact
# 3. Delete Contact
# 4. Display Phonebook
# 5. Exit
# 3 not found in the phonebook.
#
# Phonebook Menu:
# 1. Add Contact
# 2. Search Contact
# 3. Delete Contact
# ...

# %%
#02_pop_up_shop
def calculate_total_cost():
    fruits_price = {
        "apple": 5.0,
        "banana": 3.0,
        "orange": 4.0,
        "grape": 6.0,
        "kiwi": 7.0
    }

    total_cost = 0

    for fruit, price in fruits_price.items():
        while True:
            try:
                quantity = int(input(f"How many {fruit}s do you want? "))
                if quantity < 0:
                    print("Invalid input. Quantity cannot be negative.")
                    continue
                total_cost += price * quantity
                break
            except ValueError:
                print("Invalid input. Please enter a valid number.")

    print(f"\nTotal cost: ${total_cost:.2f}")
calculate_total_cost()

# %%
import hashlib
# powerfull password
def hash_password(password):
  return hashlib.sha256(password.encode()).hexdigest()

stored_logins={
    "user1":hash_password("password123"),
    "user2":hash_password("adminpass"),

}
def login(email,password):
    if email in stored_logins:
       return stored_logins[email] == hash_password(password)
    return False
email = input("Enter your email: ")
password = input("Enter your password: ")
if login(email, password):
    print("Login successful!")
else:
    print("Login failed. Invalid email or password.")
