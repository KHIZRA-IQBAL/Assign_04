# %% [markdown]
# <a href="https://colab.research.google.com/github/KHIZRA-IQBAL/Assign_04/blob/main/02_intermediate_Control_Flow_for.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import random

total_rounds = 5

def main():
    print("Welcome to the High Low Game!")
    print("I am thinking of a number between 1 and 100.")
    print("Can you guess what it is?")

    your_score = 0

    for i in range(total_rounds):
        print(f"\nRound {i + 1}")

        computer_number = random.randint(1, 100)
        your_number = random.randint(1, 100)

        print("Your number is:", your_number)

        choice = input("Is it higher or lower than the computer's number? ").lower()

        higher_and_correct = choice == "higher" and your_number > computer_number
        lower_and_correct = choice == "lower" and your_number < computer_number

        if higher_and_correct or lower_and_correct:
            print(f"You were right! The computer's number was {computer_number}.")
            your_score += 1
        else:
            print(f"That's incorrect. The computer's number was {computer_number}.")
            break

        print(f"Your score is: {your_score}")

    print("\nThanks for playing!")

main()

# %%
from ast import Index
#list and dicts
my_list = ["apple","mango","peach"]
def acess_element(my_list, index):
  """return the element at the specified index in the list"""
  if 0 <= index < len(my_list):
      return f"Element at index {index}:{my_list[index]}"
  else:
      return "Index out of range"
def modify_element(my_list,index,new_value):
  """ modifies the element at the specified index in the list"""
  if 0 <= index < len(my_list):
    old_value = my_list[index]
    new_value = input("Enter the new value for the element:")
    my_list[index] = new_value
    return f"element at least {index} modifies from {old_value} to {new_value}"
  else:
    return "Index out of range"
def slice_list(my_list,start,end):
  if 0 <= start < len(my_list) and 0 <= end <= len(my_list):
    return my_list[start:end]
  return "Index out of range"
def list_game():
  print("Welcome to the list game!")
my_list = ["apple","mango","peach"]
while True:
   print("Here is your list:",my_list)

print("select an operation")
print("1.Access Element ")
print("2.Modify Element")
print("3.Slice List")
print("4.Quit")

choice = input("Enter your choice (1/2/3/4):")


if choice == "1":
  index = int(input("Enter the index of the element you want to access:"))
  print(access_element(my_list,index))

elif choice == "2":
    index = int(input("Enter the index of the element you want to modify:"))
    new_value = input("Enter the new value for the element:")
    print(modify_element(my_list,index,new_value))

elif choice == "3":
    start = int(input("Enter the start index of the slice:"))
    end = int(input("Enter the end index of the slice:"))
    print(slice_list(my_list,start,end))

elif choice == "4":
    print("Thanks for playing!")

else:
    print("Invalid choice. Please select a valid option (1/2/3/4).")

acess_element(my_list,index)
modify_element(my_list,index,new_value)
slice_list(my_list,start,end)
list_game()

# %%
# List and dicts
my_list = ["apple", "mango", "peach"]

def access_element(my_list, index):
    """Return the element at the specified index in the list"""
    if 0 <= index < len(my_list):
        return f"Element at index {index}: {my_list[index]}"
    else:
        return "Index out of range"

def modify_element(my_list, index, new_value):
    """Modifies the element at the specified index in the list"""
    if 0 <= index < len(my_list):
        old_value = my_list[index]
        my_list[index] = new_value
        return f"Element at index {index} modified from {old_value} to {new_value}"
    else:
        return "Index out of range"

def slice_list(my_list, start, end):
    if 0 <= start < len(my_list) and 0 <= end <= len(my_list):
        return my_list[start:end]
    return "Index out of range"

def list_game():
    print("Welcome to the list game!")
    while True:
        print("\nHere is your list:", my_list)
        print("Select an operation:")
        print("1. Access Element")
        print("2. Modify Element")
        print("3. Slice List")
        print("4. Quit")

        choice = input("Enter your choice (1/2/3/4): ")

        if choice == "1":
            index = int(input("Enter the index of the element you want to access: "))
            print(access_element(my_list, index))

        elif choice == "2":
            index = int(input("Enter the index of the element you want to modify: "))
            new_value = input("Enter the new value for the element: ")
            print(modify_element(my_list, index, new_value))

        elif choice == "3":
            start = int(input("Enter the start index of the slice: "))
            end = int(input("Enter the end index of the slice: "))
            print(slice_list(my_list, start, end))

        elif choice == "4":
            print("Thanks for playing!")
            break

        else:
            print("Invalid choice. Please select a valid option (1/2/3/4).")


list_game()
# Out:
# Welcome to the list game!
#
# Here is your list: ['apple', 'mango', 'peach']
# Select an operation:
# 1. Access Element
# 2. Modify Element
# 3. Slice List
# 4. Quit
# Enter your choice (1/2/3/4): 2
# Enter the index of the element you want to modify: 2
# Enter the new value for the element: strawberry
# Element at index 2 modified from peach to strawberry
#
# Here is your list: ['apple', 'mango', 'strawberry']
# Select an operation:
# 1. Access Element
# 2. Modify Element
# 3. Slice List
# 4. Quit
# Enter your choice (1/2/3/4): 2
# Enter the index of the element you want to modify: 2
# Enter the new value for the element: 2
# Element at index 2 modified from strawberry to 2
#
# Here is your list: ['apple', 'mango', '2']
# Select an operation:
# 1. Access Element
# 2. Modify Element
# 3. Slice List
# 4. Quit
# Enter your choice (1/2/3/4):
# Invalid choice. Please select a valid option (1/2/3/4).
#
# Here is your list: ['apple', 'mango', '2']
# Select an operation:
# ...
